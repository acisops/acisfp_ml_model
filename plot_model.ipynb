# %%
from utils import FPTempDataProcessor, fields
from cheta import fetch_sci as fetch

# %%
dp = FPTempDataProcessor.from_file("dp.joblib")
# Out:
# 2025-06-19 10:28:58.236184: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-06-19 10:28:58.236208: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-06-19 10:28:58.236214: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-06-19 10:28:58.236231: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-06-19 10:28:58.236244: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
msids = dp.fetch("2025:001", "2025:140")

# %%
fig = dp.test_plots(msids)
# Out:
# 2025-06-19 10:29:01.847267: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1142/1142 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step
