# %%
from acisfp_model import ACISFPMLModel

# %%
m = ACISFPMLModel.from_file("model_2020_2025.joblib")
# Out:
# 2025-06-19 14:36:20.644197: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-06-19 14:36:20.644264: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-06-19 14:36:20.644330: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-06-19 14:36:20.644375: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-06-19 14:36:20.644392: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
msids = m.fetch_data("2025:001", "2025:140")

# %%
fig = m.test_plots(msids)
# Out:
# 2025-06-19 14:36:24.245325: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1142/1142 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step

# %%
fig.savefig("dashboard_2025.png", bbox_inches="tight")
